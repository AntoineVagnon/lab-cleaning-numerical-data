# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, Normalizer, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv', index_col=0)
display(df)
# Out:
#                State  Customer Lifetime Value Response  Coverage Education  \
# Customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
#          Effective To Date EmploymentStatus Gender  Income Location Code  ...  \
# Customer                                                                  ...
# BU79786            2/24/11         Employed      F   56274      Suburban  ...
# QZ44356            1/31/11       Unemployed      F       0      Suburban  ...
# AI49188            2/19/11         Employed      F   48767      Suburban  ...
# WW63253            1/20/11       Unemployed      M       0      Suburban  ...
# HB64268             2/3/11         Employed      M   43836         Rural  ...
# ...                    ...              ...    ...     ...           ...  ...
# LA72316            2/10/11         Employed      M   71941         Urban  ...
# PK87824            2/12/11         Employed      F   21604      Suburban  ...
# TD14365             2/6/11       Unemployed      M       0      Suburban  ...
# UP19263             2/3/11         Employed      M   21941      Suburban  ...
# Y167826            2/14/11       Unemployed      M       0      Suburban  ...
#
#          Months Since Policy Inception  Number of Open Complaints  \
# Customer
# BU79786                              5                          0
# QZ44356                             42                          0
# AI49188                             38                          0
# WW63253                             65                          0
# HB64268                             44                          0
# ...                                ...                        ...
# LA72316                             89                          0
# PK87824                             28                          0
# TD14365                             37                          3
# UP19263                              3                          0
# Y167826                             90                          0
#
#           Number of Policies     Policy Type        Policy  Renew Offer Type  \
# Customer
# BU79786                    1  Corporate Auto  Corporate L3            Offer1
# QZ44356                    8   Personal Auto   Personal L3            Offer3
# AI49188                    2   Personal Auto   Personal L3            Offer1
# WW63253                    7  Corporate Auto  Corporate L2            Offer1
# HB64268                    1   Personal Auto   Personal L1            Offer1
# ...                      ...             ...           ...               ...
# LA72316                    2   Personal Auto   Personal L1            Offer2
# PK87824                    1  Corporate Auto  Corporate L3            Offer1
# TD14365                    2  Corporate Auto  Corporate L2            Offer1
# UP19263                    3   Personal Auto   Personal L2            Offer3
# Y167826                    1  Corporate Auto  Corporate L3            Offer4
#
#          Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# Customer
# BU79786          Agent         384.811147   Two-Door Car      Medsize
# QZ44356          Agent        1131.464935  Four-Door Car      Medsize
# AI49188          Agent         566.472247   Two-Door Car      Medsize
# WW63253    Call Center         529.881344            SUV      Medsize
# HB64268          Agent         138.130879  Four-Door Car      Medsize
# ...                ...                ...            ...          ...
# LA72316            Web         198.234764  Four-Door Car      Medsize
# PK87824         Branch         379.200000  Four-Door Car      Medsize
# TD14365         Branch         790.784983  Four-Door Car      Medsize
# UP19263         Branch         691.200000  Four-Door Car        Large
# Y167826    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 23 columns]

# %%
customer_df.shape
# Out:
# (9134, 23)

# %%
customer_df.dtypes
# Out:
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# Vehicle Size                      object
# dtype: object

# %%
customer_df.isna().sum()
# Out:
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
customer_df.corr()['Customer Lifetime Value'].sort_values(ascending=False)
# Out:
# Customer Lifetime Value          1.000000
# Monthly Premium Auto             0.396262
# Total Claim Amount               0.226451
# Income                           0.024366
# Number of Policies               0.021955
# Months Since Last Claim          0.011517
# Months Since Policy Inception    0.009418
# Number of Open Complaints       -0.036343
# Name: Customer Lifetime Value, dtype: float64

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9134 entries, BU79786 to Y167826
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          9134 non-null   object
#  1   Customer Lifetime Value        9134 non-null   float64
#  2   Response                       9134 non-null   object
#  3   Coverage                       9134 non-null   object
#  4   Education                      9134 non-null   object
#  5   Effective To Date              9134 non-null   object
#  6   EmploymentStatus               9134 non-null   object
#  7   Gender                         9134 non-null   object
#  8   Income                         9134 non-null   int64
#  9   Location Code                  9134 non-null   object
#  10  Marital Status                 9134 non-null   object
#  11  Monthly Premium Auto           9134 non-null   int64
#  12  Months Since Last Claim        9134 non-null   int64
#  13  Months Since Policy Inception  9134 non-null   int64
#  14  Number of Open Complaints      9134 non-null   int64
#  15  Number of Policies             9134 non-null   int64
#  16  Policy Type                    9134 non-null   object
#  17  Policy                         9134 non-null   object
#  18  Renew Offer Type               9134 non-null   object
#  19  Sales Channel                  9134 non-null   object
#  20  Total Claim Amount             9134 non-null   float64
#  21  Vehicle Class                  9134 non-null   object
#  22  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(15)
# memory usage: 1.7+ MB

# %%
#Cleaning all the column titles to switch with PE8 Format

customer_df.columns = customer_df.columns.str.lower()

customer_df.columns = customer_df.columns.str.replace(' ', '_', regex=False)

customer_df = customer_df.rename(columns={
   'employmentstatus': 'employment_status'
})

customer_df
# Out:
#                state  customer_lifetime_value response  coverage education  \
# Customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
#          effective_to_date employment_status gender  income location_code  \
# Customer
# BU79786            2/24/11          Employed      F   56274      Suburban
# QZ44356            1/31/11        Unemployed      F       0      Suburban
# AI49188            2/19/11          Employed      F   48767      Suburban
# WW63253            1/20/11        Unemployed      M       0      Suburban
# HB64268             2/3/11          Employed      M   43836         Rural
# ...                    ...               ...    ...     ...           ...
# LA72316            2/10/11          Employed      M   71941         Urban
# PK87824            2/12/11          Employed      F   21604      Suburban
# TD14365             2/6/11        Unemployed      M       0      Suburban
# UP19263             2/3/11          Employed      M   21941      Suburban
# Y167826            2/14/11        Unemployed      M       0      Suburban
#
#           ... months_since_policy_inception  number_of_open_complaints  \
# Customer  ...
# BU79786   ...                             5                          0
# QZ44356   ...                            42                          0
# AI49188   ...                            38                          0
# WW63253   ...                            65                          0
# HB64268   ...                            44                          0
# ...       ...                           ...                        ...
# LA72316   ...                            89                          0
# PK87824   ...                            28                          0
# TD14365   ...                            37                          3
# UP19263   ...                             3                          0
# Y167826   ...                            90                          0
#
#           number_of_policies     policy_type        policy  renew_offer_type  \
# Customer
# BU79786                    1  Corporate Auto  Corporate L3            Offer1
# QZ44356                    8   Personal Auto   Personal L3            Offer3
# AI49188                    2   Personal Auto   Personal L3            Offer1
# WW63253                    7  Corporate Auto  Corporate L2            Offer1
# HB64268                    1   Personal Auto   Personal L1            Offer1
# ...                      ...             ...           ...               ...
# LA72316                    2   Personal Auto   Personal L1            Offer2
# PK87824                    1  Corporate Auto  Corporate L3            Offer1
# TD14365                    2  Corporate Auto  Corporate L2            Offer1
# UP19263                    3   Personal Auto   Personal L2            Offer3
# Y167826                    1  Corporate Auto  Corporate L3            Offer4
#
#          sales_channel total_claim_amount  vehicle_class vehicle_size
# Customer
# BU79786          Agent         384.811147   Two-Door Car      Medsize
# QZ44356          Agent        1131.464935  Four-Door Car      Medsize
# AI49188          Agent         566.472247   Two-Door Car      Medsize
# WW63253    Call Center         529.881344            SUV      Medsize
# HB64268          Agent         138.130879  Four-Door Car      Medsize
# ...                ...                ...            ...          ...
# LA72316            Web         198.234764  Four-Door Car      Medsize
# PK87824         Branch         379.200000  Four-Door Car      Medsize
# TD14365         Branch         790.784983  Four-Door Car      Medsize
# UP19263         Branch         691.200000  Four-Door Car        Large
# Y167826    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 23 columns]

# %%
#Fix the data types. The column to change is effective_to_date (to get only years and month) to be able to exploit this information correctly. 

#First I need to convert the column at the date format
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])
customer_df

#Then, I split date in year and month
customer_df['Month'] = customer_df['effective_to_date'].dt.month
customer_df['Month']

customer_df1 = customer_df.drop('effective_to_date', axis=1)

customer_df1
# Out:
#                state  customer_lifetime_value response  coverage education  \
# Customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
#          employment_status gender  income location_code marital_status  ...  \
# Customer                                                                ...
# BU79786           Employed      F   56274      Suburban        Married  ...
# QZ44356         Unemployed      F       0      Suburban         Single  ...
# AI49188           Employed      F   48767      Suburban        Married  ...
# WW63253         Unemployed      M       0      Suburban        Married  ...
# HB64268           Employed      M   43836         Rural         Single  ...
# ...                    ...    ...     ...           ...            ...  ...
# LA72316           Employed      M   71941         Urban        Married  ...
# PK87824           Employed      F   21604      Suburban       Divorced  ...
# TD14365         Unemployed      M       0      Suburban         Single  ...
# UP19263           Employed      M   21941      Suburban        Married  ...
# Y167826         Unemployed      M       0      Suburban         Single  ...
#
#           number_of_open_complaints  number_of_policies     policy_type  \
# Customer
# BU79786                           0                   1  Corporate Auto
# QZ44356                           0                   8   Personal Auto
# AI49188                           0                   2   Personal Auto
# WW63253                           0                   7  Corporate Auto
# HB64268                           0                   1   Personal Auto
# ...                             ...                 ...             ...
# LA72316                           0                   2   Personal Auto
# PK87824                           0                   1  Corporate Auto
# TD14365                           3                   2  Corporate Auto
# UP19263                           0                   3   Personal Auto
# Y167826                           0                   1  Corporate Auto
#
#                 policy  renew_offer_type sales_channel total_claim_amount  \
# Customer
# BU79786   Corporate L3            Offer1         Agent         384.811147
# QZ44356    Personal L3            Offer3         Agent        1131.464935
# AI49188    Personal L3            Offer1         Agent         566.472247
# WW63253   Corporate L2            Offer1   Call Center         529.881344
# HB64268    Personal L1            Offer1         Agent         138.130879
# ...                ...               ...           ...                ...
# LA72316    Personal L1            Offer2           Web         198.234764
# PK87824   Corporate L3            Offer1        Branch         379.200000
# TD14365   Corporate L2            Offer1        Branch         790.784983
# UP19263    Personal L2            Offer3        Branch         691.200000
# Y167826   Corporate L3            Offer4   Call Center         369.600000
#
#           vehicle_class vehicle_size  Month
# Customer
# BU79786    Two-Door Car      Medsize      2
# QZ44356   Four-Door Car      Medsize      1
# AI49188    Two-Door Car      Medsize      2
# WW63253             SUV      Medsize      1
# HB64268   Four-Door Car      Medsize      2
# ...                 ...          ...    ...
# LA72316   Four-Door Car      Medsize      2
# PK87824   Four-Door Car      Medsize      2
# TD14365   Four-Door Car      Medsize      2
# UP19263   Four-Door Car        Large      2
# Y167826    Two-Door Car      Medsize      2
#
# [9134 rows x 23 columns]

# %%
customer_df1['Month'].value_counts()
# Out:
# 1    4898
# 2    4236
# Name: Month, dtype: int64

# %%
corr_matrix=customer_df1.corr(method='pearson')
fig, ax = plt.subplots(figsize=(10, 10))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
#The correlation Matrix shows that the monthly premium auto and the 
#total claim amount are the 2 variables that are the moste correclated to our customer lifetime value.
#We observe as well a negative correlation with the number of complaints which is logic because they 
#are less satisfied customers.

# %%
#Let's plot each variable to have a better view of the data. 

sns.boxplot(customer_df1['monthly_premium_auto'])
# Out:
# <Axes: >

# %%
sns.boxplot(customer_df1['total_claim_amount'])
# Out:
# <Axes: >

# %%
sns.boxplot(customer_df1['customer_lifetime_value'])
# Out:
# <Axes: >

# %%
#We can see that most of the customer have a life time value below 10000 but we still have a lorge amount of customer above 15000

# %%
sns.distplot(customer_df1['customer_lifetime_value'])
# Out:
# <Axes: xlabel='customer_lifetime_value', ylabel='Density'>

# %%
#This graph confirm the previous analysis with a long tail on the right.
#nowing that we have a large sample of client with a lifetime value above 15000 it could be interesting to focus on these ones.

# %%
customer_df1[(customer_df1['customer_lifetime_value'] > 15000) & (customer_df1['customer_lifetime_value'] < 30000)]
# Out:
#                state  customer_lifetime_value response  coverage  \
# Customer
# DY87989       Oregon              24127.50402      Yes     Basic
# YH23384      Arizona              24127.50402      Yes     Basic
# UL64533       Nevada              18975.45611       No  Extended
# NN71951   California              24261.01777       No     Basic
# PY70169       Oregon              22643.83478       No     Basic
# ...              ...                      ...      ...       ...
# CZ57208   California              15245.25495       No     Basic
# FH43628   California              25464.82059      Yes  Extended
# CB59349   California              16261.58550       No  Extended
# RX91025   California              19872.26200       No   Premium
# LA72316   California              23405.98798       No     Basic
#
#                      education employment_status gender  income location_code  \
# Customer
# DY87989               Bachelor     Medical Leave      M   14072      Suburban
# YH23384               Bachelor     Medical Leave      M   14072      Suburban
# UL64533   High School or Below          Employed      M   65999         Urban
# NN71951   High School or Below          Employed      F   66525         Rural
# PY70169   High School or Below          Employed      M   93011         Rural
# ...                        ...               ...    ...     ...           ...
# CZ57208               Bachelor          Employed      F   30205      Suburban
# FH43628                College           Retired      F   13663      Suburban
# CB59349                 Master          Employed      M   60646      Suburban
# RX91025   High School or Below        Unemployed      M       0      Suburban
# LA72316               Bachelor          Employed      M   71941         Urban
#
#          marital_status  ...  number_of_open_complaints  number_of_policies  \
# Customer                 ...
# DY87989        Divorced  ...                          0                   2
# YH23384        Divorced  ...                          0                   2
# UL64533         Married  ...                          0                   6
# NN71951         Married  ...                          0                   2
# PY70169        Divorced  ...                          0                   2
# ...                 ...  ...                        ...                 ...
# CZ57208          Single  ...                          0                   4
# FH43628          Single  ...                          0                   2
# CB59349         Married  ...                          0                   2
# RX91025          Single  ...                          0                   2
# LA72316         Married  ...                          0                   2
#
#              policy_type        policy  renew_offer_type sales_channel  \
# Customer
# DY87989   Corporate Auto  Corporate L3            Offer1         Agent
# YH23384    Personal Auto   Personal L3            Offer1         Agent
# UL64533   Corporate Auto  Corporate L2            Offer2         Agent
# NN71951    Personal Auto   Personal L3            Offer1         Agent
# PY70169    Personal Auto   Personal L3            Offer4         Agent
# ...                  ...           ...               ...           ...
# CZ57208    Personal Auto   Personal L3            Offer1         Agent
# FH43628    Personal Auto   Personal L2            Offer1        Branch
# CB59349    Personal Auto   Personal L3            Offer2         Agent
# RX91025    Personal Auto   Personal L3            Offer1         Agent
# LA72316    Personal Auto   Personal L1            Offer2           Web
#
#          total_claim_amount  vehicle_class vehicle_size  Month
# Customer
# DY87989          511.200000  Four-Door Car      Medsize      1
# YH23384          511.200000  Four-Door Car      Medsize      1
# UL64533          615.927769     Luxury SUV      Medsize      1
# NN71951          104.331355            SUV      Medsize      1
# PY70169          281.451042            SUV      Medsize      2
# ...                     ...            ...          ...    ...
# CZ57208         1329.957905     Luxury SUV        Large      1
# FH43628          465.600000  Four-Door Car        Small      2
# CB59349          643.200000            SUV      Medsize      1
# RX91025         1950.725547            SUV        Small      1
# LA72316          198.234764  Four-Door Car      Medsize      2
#
# [782 rows x 23 columns]

# %%
sns.distplot(customer_df1[(customer_df1['customer_lifetime_value'] > 15000)]['customer_lifetime_value'])
# Out:
# <Axes: xlabel='customer_lifetime_value', ylabel='Density'>

# %%
sns.boxplot(customer_df1[(customer_df1['customer_lifetime_value'] > 15000)]['customer_lifetime_value'])
# Out:
# <Axes: >

# %%
sns.boxplot(customer_df1[(customer_df1['customer_lifetime_value'] > 15000) & (customer_df1['customer_lifetime_value'] < 30000)]['customer_lifetime_value'])
# Out:
# <Axes: >

# %%
for col in customer_df1.select_dtypes(np.object):
    sns.displot(customer_df1[col])
    plt.show()

# %%
#We vizualize the categorial data where customer lifetime value is between 15000 and 30000 to identifie outliers.  

for col in customer_df1.select_dtypes(np.object):
    sns.displot(customer_df1[(customer_df1['customer_lifetime_value'] > 15000) & (customer_df1['customer_lifetime_value'] < 30000)][col])
    plt.show()

# %%
#The variables with outliers are: "education", "employement_status", 'policy_type', "policy"
#We can see as well that there are no missing data in the dataset
